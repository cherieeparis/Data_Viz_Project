# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install openpyxl

# %%
import os
import pandas as pd


drive_base_path = '/content/drive/My Drive/'

files = os.listdir(drive_base_path)
print(files)
# Out:
# ['EBSCO', 'Colab Notebooks', 'Untitled0.ipynb', 'Slides', 'Linear_Ridge_Lasso Regression_092623.ipynb', 'Untitled', 'GR5067_Group3.pptx', 'DA file ', 'firstpresentation-nlp.gslides', 'nlp final paper.gdoc', 'CherieXu_Resume.pdf', 'NLP-coursework', 'time series - coursework', 'Data viz final project', 'Priceline project activity log - Cherie.gsheet', 'Accountant for Consultant', 'Notability backup']

# %%
folder_path = '/content/drive/My Drive/Data viz final project/LCA_Data'
files_in_folder = os.listdir(folder_path)
print(files_in_folder)
# Out:
# ['LCA_Disclosure_Data_FY2023_Q4.xlsx', 'LCA_Disclosure_Data_FY2023_Q1.xlsx', 'LCA_Disclosure_Data_FY2022_Q1.xlsx', 'LCA_Disclosure_Data_FY2022_Q2.xlsx', 'LCA_Disclosure_Data_FY2022_Q4.xlsx', 'LCA_Disclosure_Data_FY2023_Q3.xlsx', 'LCA_Disclosure_Data_FY2022_Q3.xlsx', 'LCA_Disclosure_Data_FY2021_Q1.xlsx', 'LCA_Disclosure_Data_FY2021_Q4.xlsx', 'LCA_Disclosure_Data_FY2023_Q2.xlsx', 'LCA_Disclosure_Data_FY2020_Q1.xlsx', 'LCA_Disclosure_Data_FY2020_Q2.xlsx', 'LCA_Disclosure_Data_FY2020_Q3.xlsx', 'LCA_Disclosure_Data_FY2020_Q4.xlsx', 'LCA_Disclosure_Data_FY2021_Q2.xlsx', 'LCA_Disclosure_Data_FY2021_Q3.xlsx', 'H-1B_Disclosure_Data_FY2019.xlsx', 'combined_data.csv', 'Data_Merge.ipynb', 'LCA_2020-2023.csv', 'LCA2019.csv', 'LCA2019-2023.csv']

# %%
 #selected cols only
 # will add a few more cols for need
 cols_to_load = ['RECEIVED_DATE','DECISION_DATE','ORIGINAL_CERT_DATE','VISA_CLASS','JOB_TITLE', 'CASE_STATUS','SOC_TITLE','FULL_TIME_POSITION',
                 'BEGIN_DATE','END_DATE','EMPLOYER_NAME','EMPLOYER_CITY','EMPLOYER_STATE','EMPLOYER_POSTAL_CODE','NAICS_CODE',
                 'WAGE_RATE_OF_PAY_FROM','WAGE_RATE_OF_PAY_TO','WAGE_UNIT_OF_PAY','PREVAILING_WAGE','PW_UNIT_OF_PAY','PW_WAGE_LEVEL',
                 'WORKSITE_CITY','CASE_STATUS','WORKSITE_POSTAL_CODE']

# %%
#2023
file_path_2023_Q4 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2023_Q4.xlsx')
df_2023_Q4 = pd.read_excel(file_path_2023_Q4, usecols=cols_to_load)

file_path_2023_Q3 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2023_Q3.xlsx')
df_2023_Q3 = pd.read_excel(file_path_2023_Q3, usecols=cols_to_load)

file_path_2023_Q2 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2023_Q2.xlsx')
df_2023_Q2 = pd.read_excel(file_path_2023_Q2, usecols=cols_to_load)

file_path_2023_Q1 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2023_Q1.xlsx')
df_2023_Q1 = pd.read_excel(file_path_2023_Q1, usecols=cols_to_load)


#2022
file_path_2022_Q4 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2022_Q4.xlsx')
df_2022_Q4 = pd.read_excel(file_path_2022_Q4, usecols=cols_to_load)

file_path_2022_Q3 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2022_Q3.xlsx')
df_2022_Q3 = pd.read_excel(file_path_2022_Q3, usecols=cols_to_load)

file_path_2022_Q2 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2022_Q2.xlsx')
df_2022_Q2 = pd.read_excel(file_path_2022_Q2, usecols=cols_to_load)

file_path_2022_Q1 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2022_Q1.xlsx')
df_2022_Q1 = pd.read_excel(file_path_2022_Q1, usecols=cols_to_load)

#2021
file_path_2021_Q1 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2021_Q1.xlsx')
df_2021_Q1 = pd.read_excel(file_path_2021_Q1, usecols=cols_to_load)

file_path_2021_Q2 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2021_Q2.xlsx')
df_2021_Q2 = pd.read_excel(file_path_2021_Q2, usecols=cols_to_load)

file_path_2021_Q3 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2021_Q3.xlsx')
df_2021_Q3 = pd.read_excel(file_path_2021_Q3, usecols=cols_to_load)

file_path_2021_Q4 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2021_Q4.xlsx')
df_2021_Q4 = pd.read_excel(file_path_2021_Q4, usecols=cols_to_load)



file_path_2020_Q1 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2020_Q1.xlsx')
df_2020_Q1 = pd.read_excel(file_path_2020_Q1, usecols=cols_to_load)

file_path_2020_Q2 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2020_Q2.xlsx')
df_2020_Q2 = pd.read_excel(file_path_2020_Q2, usecols=cols_to_load)

file_path_2020_Q3 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2020_Q3.xlsx')
df_2020_Q3 = pd.read_excel(file_path_2020_Q3, usecols=cols_to_load)

file_path_2020_Q4 = os.path.join(folder_path, 'LCA_Disclosure_Data_FY2020_Q4.xlsx')
df_2020_Q4 = pd.read_excel(file_path_2020_Q4, usecols=cols_to_load)

# %%
# combine 2020-2023 Q files
combined_df = pd.concat([df_2020_Q1,df_2020_Q2,df_2020_Q3,df_2020_Q4,df_2021_Q1,df_2021_Q2,df_2021_Q3,df_2021_Q4,df_2022_Q1,df_2022_Q2,df_2022_Q3,df_2022_Q4,df_2023_Q1,df_2023_Q2,df_2023_Q3,df_2023_Q4],
                         ignore_index=True)

# %%
print(combined_df)
# Out:
#                    CASE_STATUS RECEIVED_DATE DECISION_DATE ORIGINAL_CERT_DATE  \
# 0                    Certified    2019-09-25    2019-10-01                NaT
# 1                    Certified    2019-09-25    2019-10-01                NaT
# 2                    Certified    2019-09-25    2019-10-01                NaT
# 3                    Certified    2019-09-25    2019-10-01                NaT
# 4                    Certified    2019-09-25    2019-10-01                NaT
# ...                        ...           ...           ...                ...
# 2674325              Withdrawn    2023-06-29    2023-07-02                NaT
# 2674326              Withdrawn    2023-06-29    2023-07-02                NaT
# 2674327              Withdrawn    2023-06-28    2023-07-02                NaT
# 2674328  Certified - Withdrawn    2021-07-30    2023-07-01         2021-08-06
# 2674329  Certified - Withdrawn    2021-07-13    2023-07-01         2021-07-20
#
# ...

# %%
#export merge data 2020-2023
combined_df.to_csv('/content/drive/My Drive/Data viz final project/LCA_Data/LCA_2020-2023.csv', index=False)
print("save sucess:'/content/drive/My Drive/Data viz final project/LCA_Data/LCA_2020-2022.csv'")
# Out:
# save sucess:'/content/drive/My Drive/Data viz final project/LCA_Data/LCA_2020-2022.csv'

# %%
# read 2020-2023 merge data
file_path_c= os.path.join(folder_path, 'LCA_2020-2023.csv')
df_c = pd.read_csv(file_path_c)
# Out:
# <ipython-input-11-0dc9f157fd76>:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_c = pd.read_csv(file_path_c)

# %%
# read 2019 individually
file_path_2019 = os.path.join(folder_path, 'H-1B_Disclosure_Data_FY2019.xlsx')
df_2019 = pd.read_excel(file_path_2019, engine='openpyxl')

# %%
print(df_2019)

# %%
selected_cols_df_2019 = df_2019[['EMPLOYER_NAME', 'NAICS_CODE', 'VISA_CLASS', 'SOC_TITLE', 'EMPLOYER_POSTAL_CODE', 'FULL_TIME_POSITION', 'EMPLOYER_STATE', 'EMPLOYER_CITY', 'ORIGINAL_CERT_DATE', 'DECISION_DATE', 'JOB_TITLE',
'CASE_SUBMITTED', 'PERIOD_OF_EMPLOYMENT_START_DATE', 'PERIOD_OF_EMPLOYMENT_END_DATE', 'WAGE_RATE_OF_PAY_FROM_1','WAGE_RATE_OF_PAY_TO_1', 'WAGE_UNIT_OF_PAY_1', "PREVAILING_WAGE_1","PW_UNIT_OF_PAY_1", 'PW_WAGE_LEVEL_1',
                'WORKSITE_CITY_1','WORKSITE_POSTAL_CODE_1','CASE_STATUS']]


#selected_cols_df_2019 = df_2019[['EMPLOYER_NAME', 'NAICS_CODE', 'VISA_CLASS', 'SOC_TITLE', 'EMPLOYER_POSTAL_CODE', 'FULL_TIME_POSITION', 'EMPLOYER_STATE', 'EMPLOYER_CITY', 'ORIGINAL_CERT_DATE', 'DECISION_DATE', 'JOB_TITLE',
#'CASE_SUBMITTED', 'PERIOD_OF_EMPLOYMENT_START_DATE', 'PERIOD_OF_EMPLOYMENT_END_DATE','WAGE_RATE_OF_PAY_FROM_1','WAGE_RATE_OF_PAY_TO_1', 'WAGE_UNIT_OF_PAY_1', "PREVAILING_WAGE_1","PW_UNIT_OF_PAY_1", 'PW_WAGE_LEVEL_1']]

# %%
selected_cols_df_2019.to_csv('/content/drive/My Drive/Data viz final project/LCA_Data/LCA2019.csv', index=False)
#print("save sucess:'/content/drive/My Drive/Data viz final project/LCA_Data/LCA2019.csv'")

# %%
#df_2019.to_csv('/content/drive/My Drive/Data viz final project/LCA_Data/LCA2019.csv', index=False)
#print("save sucess:'/content/drive/My Drive/Data viz final project/LCA_Data/LCA2019.csv'")

# %%
file_path_c19= os.path.join(folder_path, 'LCA2019.csv')
df_c19 = pd.read_csv(file_path_c19)

# %%
print(df_c19)
# Out:
#                                    EMPLOYER_NAME  NAICS_CODE      VISA_CLASS  \
# 0                         R/GA MEDIA GROUP, INC.    541810.0            H-1B
# 1                          MOTHER INDUSTRIES LLC    541810.0  E-3 Australian
# 2                         WE ARE UNLIMITED, INC.    541810.0  E-3 Australian
# 3                            HELLO ELEPHANT, LLC    541810.0  E-3 Australian
# 4                            HELLO ELEPHANT, LLC    541810.0  E-3 Australian
# ...                                          ...         ...             ...
# 664611  AMERICAN FAMILY MUTUAL INSURANCE COMPANY    524113.0            H-1B
# 664612                     CAPGEMINI AMERICA INC      5416.0            H-1B
# 664613                     CAPGEMINI AMERICA INC      5416.0            H-1B
# 664614                     CAPGEMINI AMERICA INC      5416.0            H-1B
# 664615                     CAPGEMINI AMERICA INC      5416.0            H-1B
#
# ...

# %%
#rename column

df_c19.rename(columns= {'CASE_SUBMITTED':'RECEIVED_DATE', 'PERIOD_OF_EMPLOYMENT_START_DATE': 'BEGIN_DATE', 'PERIOD_OF_EMPLOYMENT_END_DATE':'END_DATE',
                       'WAGE_RATE_OF_PAY_FROM_1': 'WAGE_RATE_OF_PAY_FROM', 'WAGE_RATE_OF_PAY_TO_1':'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY_1':'WAGE_UNIT_OF_PAY',
                       'PREVAILING_WAGE_1':'PREVAILING_WAGE', 'PW_UNIT_OF_PAY_1':'PW_UNIT_OF_PAY','PW_WAGE_LEVEL_1':'PW_WAGE_LEVEL','WORKSITE_CITY_1':'WORKSITE_CITY','WORKSITE_POSTAL_CODE_1': 'WORKSITE_POSTAL_CODE'}, inplace=True)

# %%
print(df_c19)

# %%
print(df_c)
# Out:
#                    CASE_STATUS RECEIVED_DATE DECISION_DATE ORIGINAL_CERT_DATE  \
# 0                    Certified    2019-09-25    2019-10-01                NaN
# 1                    Certified    2019-09-25    2019-10-01                NaN
# 2                    Certified    2019-09-25    2019-10-01                NaN
# 3                    Certified    2019-09-25    2019-10-01                NaN
# 4                    Certified    2019-09-25    2019-10-01                NaN
# ...                        ...           ...           ...                ...
# 2674325              Withdrawn    2023-06-29    2023-07-02                NaN
# 2674326              Withdrawn    2023-06-29    2023-07-02                NaN
# 2674327              Withdrawn    2023-06-28    2023-07-02                NaN
# 2674328  Certified - Withdrawn    2021-07-30    2023-07-01         2021-08-06
# 2674329  Certified - Withdrawn    2021-07-13    2023-07-01         2021-07-20
#
# ...

# %%
# merge two dataframe together and export

df_19_23 = pd.concat([df_c, df_c19])

df_19_23.reset_index(drop=True, inplace=True)


df_19_23.to_csv('/content/drive/My Drive/Data viz final project/LCA_Data/LCA2019-2023.csv', index=False)

# %%
print(df_19_23)
# Out:
#         CASE_STATUS        RECEIVED_DATE        DECISION_DATE  \
# 0         Certified           2019-09-25           2019-10-01
# 1         Certified           2019-09-25           2019-10-01
# 2         Certified           2019-09-25           2019-10-01
# 3         Certified           2019-09-25           2019-10-01
# 4         Certified           2019-09-25           2019-10-01
# ...             ...                  ...                  ...
# 3338941   CERTIFIED  2018-10-09 18:10:32  2018-10-15 22:00:43
# 3338942      DENIED  2019-02-15 16:53:11  2019-02-22 10:45:38
# 3338943      DENIED  2019-02-28 01:11:11  2019-03-07 16:07:41
# 3338944      DENIED  2019-03-04 08:37:04  2019-03-08 12:01:58
# 3338945      DENIED  2019-03-14 08:14:46  2019-03-19 11:41:04
#
#         ORIGINAL_CERT_DATE VISA_CLASS                               JOB_TITLE  \
# 0                      NaN       H-1B  APPLICATION ENGINEER, OMS [15-1199.02]
# ...

# %%
#EDA

n = len(pd.unique(df_19_23['WAGE_UNIT_OF_PAY']))
print(n)
# Out:
# 6
